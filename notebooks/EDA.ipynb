# %% [markdown]
# # Exploratory Data analysis
# - Exploring the dataset to get the information about out requirement

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
filepath="../data/preprocessed_data/train.csv"

# %%
housing=pd.read_csv(filepath)

# %% [markdown]
# ## Visualizing Geographical Data

# %% [markdown]
# - It is always recommended to use scatter plot for visulaizing the geographical data when lattitudes and longitudes are provided

# %%
housing.plot(kind="scatter", x="longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# - To get more understanding with scatter plot , it is recommended to use hues or add some other parameters
# - From this one scatter we can know that geographical location is mostly California

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# From this we can observe some high density and low density areas

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, s=housing["population"]/100, label="population", 
             figsize=(10,7),c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,)
plt.legend()

# %% [markdown]
# ## Looking for Correlation
# - Since we are facing a regression problem correlation between columns with the target variable variable is very much useful

# %%
corr_matrix = housing.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15396\2466220658.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = housing.corr()

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687151
# total_rooms           0.135140
# housing_median_age    0.114146
# Unnamed: 0            0.067805
# households            0.064590
# total_bedrooms        0.047781
# population           -0.026882
# longitude            -0.047466
# latitude             -0.142673
# Name: median_house_value, dtype: float64

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [markdown]
# The most promising attribute to predict the median house value is median_income

# %%
housing.plot(kind="scatter", x="median_income", y="median_house_value",
 alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
## Exploring univariate analysis of all numerical attributes

# %%
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# # Categorical Attributes
# - since we have only categorial attribute

# %%
housing['ocean_proximity'].value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# This is the basic EDA how can we on a dataset
